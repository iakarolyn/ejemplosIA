# %% [markdown]
# Clase de variables simples

# %%
nombre = "karolyn"
print("Mi nombre es karolyn")

print(nombre)

print("nombre")

print("Mi nombre es \n"+nombre)
# Out:
# Mi nombre es karolyn
# karolyn
# nombre
# Mi nombre es
# karolyn

# %% [markdown]
# variables complejas

# %%
usuarioTalentoTech=["karolyn", 34, False, "3134355544"]
print(usuarioTalentoTech[1])
# Out:
# 34

# %%
nombre =input("escriba su nombre ")

# %%
edad=15
edad
# Out:
# 15

# %%
diccionarioUsuario={"nombre":"karolyn","edad":34, "extranjera":False, "telefono":"315633366"}

print(diccionarioUsuario['edad'])
# Out:
# 34

# %%
peso = float(input("Ingrese su peso"))

altura = float(input("Ingrese su altura"))

imc = (peso/(altura*altura))

print(f"Su imc es  {imc}")

imprimir ="su imc es" + str(imc)

imprimir
# Out:
# Su imc es  0.16
# 'su imc es0.16'

# %%
prueba="el numero {1} ha sido cambiado {0}".format(1.23,2)
prueba
# Out:
# 'el numero 2 ha sido cambiado 1.23'

# %%
renta= int(input("Ingrese el valor de la renta"))

if(renta <10000):
    print ("Tu tipo de impositivo es 5%")
elif(renta>=10000 and renta <20000):
    print ("Tu tipo de impositivo es 15%")
elif(renta>=20000 and renta <35000):
    print ("Tu tipo de impositivo es 20%")
elif(renta>=35000 and renta <=60000):
    print ("Tu tipo de impositivo es 30%")
else:
    print ("Tu tipo de impositivo es 45%") 



def imprimir(tipoImpositivo):
    print (f"Tu tipo de impositivo es {tipoImpositivo}%")

renta= int(input("Ingrese el valor de la renta"))

if(renta <10000):
    imprimir(5)
elif(renta>=10000 and renta <20000):
    imprimir(15)
elif(renta>=20000 and renta <35000):
    imprimir(20)
elif(renta>=35000 and renta <=60000):
    imprimir(30)
else:
    imprimir(45)
